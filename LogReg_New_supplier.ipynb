# %% [markdown]
# <a href="https://colab.research.google.com/github/manugupta-or/Coursera_aiscm/blob/main/LogReg_New_supplier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('supplier_data.csv')
dataset
# Out:
#      Supplier ID   Cost  Quality  Delivery time  Reliability  Flexibility  \
# 0           1001  0.874    0.758          0.082        0.114        0.082
# 1           1002  0.972    0.694          0.955        0.963        0.244
# 2           1003  0.827    0.413          0.199        0.577        0.127
# 3           1004  0.422    0.555          0.969        0.760        0.773
# 4           1005  0.767    0.958          0.915        0.719        0.715
# ..           ...    ...      ...            ...          ...          ...
# 995         1996  0.201    0.260          0.060        0.823        0.220
# 996         1997  0.128    0.408          0.611        0.774        0.351
# 997         1998  0.910    0.308          0.381        0.818        0.671
# 998         1999  0.408    0.271          0.921        0.648        0.948
# 999         2000  0.518    0.319          0.344        0.597        0.704
#
#      Capacity  Innovation  Reputation  Financial stability  ...  \
# 0       0.871       0.240       0.166                0.478  ...
# 1       0.849       0.001       0.682                0.713  ...
# 2       0.232       0.476       0.951                0.805  ...
# 3       0.011       0.358       0.288                0.847  ...
# 4       0.553       0.651       0.133                0.578  ...
# ..        ...         ...         ...                  ...  ...
# 995     0.745       0.614       0.365                0.804  ...
# 996     0.615       0.114       0.215                0.359  ...
# 997     0.500       0.031       0.378                0.374  ...
# 998     0.562       0.050       0.061                0.627  ...
# 999     0.353       0.427       0.309                0.890  ...
#
#      Safety record  Technical expertise  Customer service  Lead time  \
# 0            0.130                0.947             0.463      0.969
# 1            0.033                0.242             0.867      0.523
# 2            0.060                0.192             0.446      0.145
# 3            0.209                0.280             0.699      0.863
# 4            0.351                0.131             0.406      0.963
# ..             ...                  ...               ...        ...
# 995          0.269                0.010             0.502      0.154
# 996          0.507                0.652             0.212      0.135
# 997          0.470                0.401             0.677      0.072
# 998          0.372                0.093             0.694      0.154
# 999          0.564                0.181             0.086      0.162
#
#      Responsiveness  Contract terms  Diversity  Sustainability  Scalability  \
# 0             0.044           0.812      0.044           0.853        0.663
# 1             0.583           0.968      0.490           0.515        0.028
# 2             0.568           0.081      0.822           0.826        0.158
# 3             0.423           0.271      0.960           0.469        0.914
# 4             0.939           0.981      0.004           0.013        0.575
# ..              ...             ...        ...             ...          ...
# 995           0.547           0.407      0.813           0.135        0.277
# 996           0.596           0.996      0.081           0.069        0.905
# 997           0.744           0.520      0.748           0.069        0.403
# 998           0.957           0.930      0.280           0.863        0.959
# 999           0.222           0.600      0.825           0.499        0.541
#
#      Supplier’s default
# 0                     0
# 1                     1
# 2                     1
# 3                     0
# 4                     0
# ..                  ...
# 995                   0
# 996                   0
# 997                   0
# 998                   0
# 999                   0
#
# [1000 rows x 22 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Supplier ID            1000 non-null   int64
#  1   Cost                   1000 non-null   float64
#  2   Quality                1000 non-null   float64
#  3   Delivery time          1000 non-null   float64
#  4   Reliability            1000 non-null   float64
#  5   Flexibility            1000 non-null   float64
#  6   Capacity               1000 non-null   float64
#  7   Innovation             1000 non-null   float64
#  8   Reputation             1000 non-null   float64
#  9   Financial stability    1000 non-null   float64
#  10  Environmental impact   1000 non-null   float64
#  11  Social responsibility  1000 non-null   float64
#  12  Safety record          1000 non-null   float64
#  13  Technical expertise    1000 non-null   float64
#  14  Customer service       1000 non-null   float64
#  15  Lead time              1000 non-null   float64
#  16  Responsiveness         1000 non-null   float64
#  17  Contract terms         1000 non-null   float64
#  18  Diversity              1000 non-null   float64
#  19  Sustainability         1000 non-null   float64
#  20  Scalability            1000 non-null   float64
#  21  Supplier’s default     1000 non-null   int64
# dtypes: float64(20), int64(2)
# memory usage: 172.0 KB

# %%
#Extracting the feature into X, 
X = dataset.iloc[:, 1:-1].values

#Extracting the target into y
y = dataset.iloc[:, -1].values
print(X)
# Out:
# [[0.874 0.758 0.082 ... 0.044 0.853 0.663]
#  [0.972 0.694 0.955 ... 0.49  0.515 0.028]
#  [0.827 0.413 0.199 ... 0.822 0.826 0.158]
#  ...
#  [0.91  0.308 0.381 ... 0.748 0.069 0.403]
#  [0.408 0.271 0.921 ... 0.28  0.863 0.959]
#  [0.518 0.319 0.344 ... 0.825 0.499 0.541]]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
test_size = 0.3, random_state = 0)

# %% [markdown]
# ## Training the Logistic Regression model on the Training set

# %%
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## Making the Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[215  12]
#  [ 29  44]]

# %%
accuracy = metrics.accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.8633333333333333

# %%
#printing classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       227
#            1       0.79      0.60      0.68        73
#
#     accuracy                           0.86       300
#    macro avg       0.83      0.77      0.80       300
# weighted avg       0.86      0.86      0.86       300

# %%
risk_prediction_data = pd.read_csv('New_supplier_data.csv')
risk_prediction_data
# Out:
#   Supplier ID   Cost  Quality  Delivery time  Reliability  Flexibility  \
# 0  Supplier 1  0.671    0.554          0.455        0.366        0.952
# 1  Supplier 2  0.674    0.393          0.688        0.507        0.693
# 2  Supplier 3  0.788    0.572          0.845        0.148        0.426
# 3  Supplier 4  0.848    0.368          0.481        0.773        0.172
# 4  Supplier 5  0.260    0.795          0.957        0.879        0.061
#
#    Capacity  Innovation  Reputation  Financial stability  ...  \
# 0     0.756       0.239       0.377                0.777  ...
# 1     0.469       0.338       0.178                0.619  ...
# 2     0.879       0.364       0.601                0.841  ...
# 3     0.206       0.154       0.481                0.763  ...
# 4     0.778       0.900       0.119                0.863  ...
#
#    Social responsibility  Safety record  Technical expertise  \
# 0                  0.318          0.143                0.679
# 1                  0.823          0.204                0.118
# 2                  0.312          0.211                0.129
# 3                  0.984          0.919                0.500
# 4                  0.316          0.728                0.447
#
#    Customer service  Lead time  Responsiveness  Contract terms  Diversity  \
# 0             0.502      0.150           0.400           0.039      0.277
# 1             0.757      0.256           0.488           0.007      0.977
# 2             0.315      0.497           0.316           0.309      0.380
# 3             0.450      0.546           0.452           0.108      0.317
# 4             0.003      0.826           0.435           0.464      0.803
#
#    Sustainability  Scalability
# 0           0.829        0.077
# 1           0.835        0.566
# 2           0.309        0.487
# 3           0.005        0.737
# 4           0.882        0.548
#
# [5 rows x 21 columns]

# %%
risk_prediction_data_features = risk_prediction_data.drop(['Supplier ID'], axis=1)

# %%
risk_prediction_data_features
# Out:
#     Cost  Quality  Delivery time  Reliability  Flexibility  Capacity  \
# 0  0.671    0.554          0.455        0.366        0.952     0.756
# 1  0.674    0.393          0.688        0.507        0.693     0.469
# 2  0.788    0.572          0.845        0.148        0.426     0.879
# 3  0.848    0.368          0.481        0.773        0.172     0.206
# 4  0.260    0.795          0.957        0.879        0.061     0.778
#
#    Innovation  Reputation  Financial stability  Environmental impact  \
# 0       0.239       0.377                0.777                 0.709
# 1       0.338       0.178                0.619                 0.388
# 2       0.364       0.601                0.841                 0.643
# 3       0.154       0.481                0.763                 0.744
# 4       0.900       0.119                0.863                 0.902
#
#    Social responsibility  Safety record  Technical expertise  \
# 0                  0.318          0.143                0.679
# 1                  0.823          0.204                0.118
# 2                  0.312          0.211                0.129
# 3                  0.984          0.919                0.500
# 4                  0.316          0.728                0.447
#
#    Customer service  Lead time  Responsiveness  Contract terms  Diversity  \
# 0             0.502      0.150           0.400           0.039      0.277
# 1             0.757      0.256           0.488           0.007      0.977
# 2             0.315      0.497           0.316           0.309      0.380
# 3             0.450      0.546           0.452           0.108      0.317
# 4             0.003      0.826           0.435           0.464      0.803
#
#    Sustainability  Scalability
# 0           0.829        0.077
# 1           0.835        0.566
# 2           0.309        0.487
# 3           0.005        0.737
# 4           0.882        0.548

# %%
Suppliers_risk_probs = classifier.predict_proba(risk_prediction_data_features)
Suppliers_risk_probs
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([[0.86023496, 0.13976504],
#        [0.49388228, 0.50611772],
#        [0.91561361, 0.08438639],
#        [0.90594794, 0.09405206],
#        [0.46492484, 0.53507516]])

# %%
Suppliers_default_probs = Suppliers_risk_probs[:, 1]
Suppliers_default_probs
# Out:
# array([0.13976504, 0.50611772, 0.08438639, 0.09405206, 0.53507516])
